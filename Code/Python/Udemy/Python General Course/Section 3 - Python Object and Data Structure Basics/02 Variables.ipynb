# %% [markdown]
# ### Assign a value to a variable
# This cell assigns the integer value `5` to the variable `a`.

# %%
a = 5

# %% [markdown]
# ### Display the value of a variable
# This cell outputs the current value stored in the variable `a`.

# %%
a
# Out:
# 5

# %% [markdown]
# ### Change the value of a variable
# This cell updates the value of `a` to `10`.

# %%
a = 10

# %% [markdown]
# ### Add a variable to itself
# This cell calculates `a + a`, which adds the current value of `a` to itself.

# %%
a + a
# Out:
# 20

# %% [markdown]
# ### Display the updated value of a variable
# This cell outputs the current value of `a` after the previous operations.

# %%
a
# Out:
# 10

# %% [markdown]
# ### Update a variable using its own value
# This cell doubles the value of `a` by adding it to itself and assigning the result back to `a`.

# %%
a = a + a

# %% [markdown]
# ### Double the value of a variable again
# This cell takes the current value of `a`, adds it to itself, and assigns the result back to `a`, effectively doubling it again.

# %%
a = a + a

# %% [markdown]
# ### Display the value after doubling
# This cell outputs the value of `a` after it has been doubled again.

# %%
a
# Out:
# 40

# %% [markdown]
# ### Check the type of a variable
# This cell displays the data type of the variable `a` using the `type()` function.

# %%
type(a)

# %% [markdown]
# ### Assign a float value to a variable
# This cell assigns the floating-point value `30.1` to the variable `a`.

# %%
a = 30.1
# Out:
# float
